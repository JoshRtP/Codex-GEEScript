# %% [markdown]
# # Step 7 — Cover crop and tillage proxy detection

# %%
from pathlib import Path
import os, sys, subprocess, json

# Run this notebook from anywhere inside the repo.
REPO = Path.cwd()
while REPO != REPO.parent and not (REPO / 'python').exists():
    REPO = REPO.parent
assert (REPO / 'python').exists(), 'Could not locate repo root. Open the notebook from inside the repo.'
os.chdir(REPO)
print('Repo root:', REPO)

# %% [markdown]
# Input should be a **field-level predictor summary table** exported from GEE or aggregated outside GEE.
# It must include the management proxy columns expected by `06_management_detection.py`.

# %%
INPUT_CSV = REPO / 'outputs' / 'tables' / 'field_predictors.csv'
OUTPUT_CSV = REPO / 'outputs' / 'tables' / 'field_management_proxies.csv'

# %%
cmd = [
    sys.executable,
    str(REPO / 'python' / '06_management_detection.py'),
    '--input', str(INPUT_CSV),
    '--output', str(OUTPUT_CSV),
]
subprocess.run(cmd, check=True)

# %%
import pandas as pd
pd.read_csv(OUTPUT_CSV)[[
    'field_id',
    'cover_crop_proxy_class', 'cover_crop_proxy_score', 'cover_crop_proxy_confidence',
    'tillage_proxy_class', 'tillage_proxy_confidence'
]].head()
